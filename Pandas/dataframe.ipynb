# %% [markdown]
# # DATAFRAME

# %%
print("I love you")
# Out:
# I love you

# %%
import pandas as pd

data = {
    'Name': ['Aariyan', 'Rashmi', 'Krishna'],
    'Age' : [24, 22, 1800],
    'Gender': ['Male', 'Female', 'Male']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age  Gender
# 0  Aariyan    24    Male
# 1   Rashmi    22  Female
# 2  Krishna  1800    Male

# %% [markdown]
# ## Creating Dataframes from list

# %%
data = [
    ['Aariyan', 24, 'SE'],
    ['Rashmi', 22, 'BA'],
    ['Krishna', 1800, 'Annoying Rashmi']
]

df1 = pd.DataFrame(data, columns= ['Name', 'Age', 'Profession'])
print(df1)
# Out:
#       Name   Age       Profession
# 0  Aariyan    24               SE
# 1   Rashmi    22               BA
# 2  Krishna  1800  Annoying Rashmi

# %% [markdown]
# ## Reading CSV file

# %%
read = pd.read_csv(r"D:\Documents\Calcutta Business School\3rd Trimester\FBA\Data Structure.xlsx")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 read = pd.read_csv(r"D:\Documents\Calcutta Business School\3rd Trimester\FBA\Data Structure.xlsx")
#
# ...

# %%
read.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 read.head()
#
# NameError: name 'read' is not defined

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Win11\Downloads\Social Media Toothless - LinkedIn CC.csv")

# %%
df.head()
# Out:
#    Day           Theme                                  Hook (First Line)  \
# 0    1    Introduction  "From college labs to enterprise codebases—thi...
# 1    2    Tech Insight  "The #1 thing I learned in my first month as a...
# 2    3  Personal Story  "I failed this interview—and it made me 10x be...
# 3    4      Tech Trend  "AI won’t replace devs—but devs using AI will ...
# 4    5            Poll  "Which is hardest for fresh grads in Software ...
#
#                                      Content Summary  \
# 0  Intro post: From B.Tech to Software Engineer a...
# 1     Share a lesson that surprised you post-joining
# 2  Vulnerable post about a rejection that shaped you
# 3  Talk about using AI tools like Copilot or ChatGPT
# 4  Poll: Communication, DSA, Development, Finding...
#
#                                                  CTA  \
# 0  "Drop a 🔥 if you're a fresh grad stepping into...
# 1  "What shocked you most when you entered the in...
# ...

# %%
df.tail()
# Out:
#     Day              Theme                                  Hook (First Line)  \
# 25   26  Behind-the-Scenes      "How I plan my week for deep focus + content"
# 26   27         Hook Story  "In 2 minutes, I gained the trust of the entir...
# 27   28          Milestone                     "We crossed 5K! This is wild."
# 28   29      Collab Invite  "Let’s co-write a carousel on modern tech ritu...
# 29   30              Recap      "30 days, 10K+ new connections, 100 lessons."
#
#                                 Content Summary  \
# 25                       Share routine and tips
# 26  Short, sharp story about interview or pitch
# 27             Community-focused gratitude post
# 28                            Collaboration CTA
# 29     Reflect on the challenge, share insights
#
#                                                   CTA  \
# 25                  "Want a template? Comment ‘Plan’"
# 26  "What’s the best thing you ever said in an int...
# ...

# %%
df.head(6)
# Out:
#    Day           Theme                                  Hook (First Line)  \
# 0    1    Introduction  "From college labs to enterprise codebases—thi...
# 1    2    Tech Insight  "The #1 thing I learned in my first month as a...
# 2    3  Personal Story  "I failed this interview—and it made me 10x be...
# 3    4      Tech Trend  "AI won’t replace devs—but devs using AI will ...
# 4    5            Poll  "Which is hardest for fresh grads in Software ...
# 5    6      Biz + Tech  "Most startups fail not due to tech—but lack o...
#
#                                      Content Summary  \
# 0  Intro post: From B.Tech to Software Engineer a...
# 1     Share a lesson that surprised you post-joining
# 2  Vulnerable post about a rejection that shaped you
# 3  Talk about using AI tools like Copilot or ChatGPT
# 4  Poll: Communication, DSA, Development, Finding...
# 5              Startup insight for non-tech audience
#
#                                                  CTA  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Day                30 non-null     int64
#  1   Theme              30 non-null     object
#  2   Hook (First Line)  30 non-null     object
#  3   Content Summary    30 non-null     object
#  4   CTA                30 non-null     object
#  5   Tag Suggestions    30 non-null     object
#  6   Format             30 non-null     object
#  7   Link               30 non-null     object
#  8   Date Posted        22 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#              Day
# count  30.000000
# mean   15.500000
# std     8.803408
# min     1.000000
# 25%     8.250000
# 50%    15.500000
# 75%    22.750000
# max    30.000000

# %%
df.columns
# Out:
# Index(['Day', 'Theme', 'Hook (First Line)', 'Content Summary', 'CTA',
#        'Tag Suggestions', 'Format', 'Link', 'Date Posted'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Day         Theme                                  Hook (First Line)  \
# 0    1  Introduction  "From college labs to enterprise codebases—thi...
# 1    2  Tech Insight  "The #1 thing I learned in my first month as a...
#
#                                      Content Summary  \
# 0  Intro post: From B.Tech to Software Engineer a...
# 1     Share a lesson that surprised you post-joining
#
#                                                  CTA  \
# 0  "Drop a 🔥 if you're a fresh grad stepping into...
# 1  "What shocked you most when you entered the in...
#
#               Tag Suggestions Format  Link Date Posted
# 0  @SaskenTech @LinkedInIndia   Text  Link   07-Jul-25
# 1       @GitHub @FreeCodeCamp   Text  Link   08-Jul-25

# %%
df["Theme"][0] = "Intro"
# Out:
# C:\Users\Win11\AppData\Local\Temp\ipykernel_18924\1779175508.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Theme"][0] = "Intro"
# ...

# %%
df.head(2)
# Out:
#    Day         Theme                                  Hook (First Line)  \
# 0    1         Intro  "From college labs to enterprise codebases—thi...
# 1    2  Tech Insight  "The #1 thing I learned in my first month as a...
#
#                                      Content Summary  \
# 0  Intro post: From B.Tech to Software Engineer a...
# 1     Share a lesson that surprised you post-joining
#
#                                                  CTA  \
# 0  "Drop a 🔥 if you're a fresh grad stepping into...
# 1  "What shocked you most when you entered the in...
#
#               Tag Suggestions Format  Link Date Posted
# 0  @SaskenTech @LinkedInIndia   Text  Link   07-Jul-25
# 1       @GitHub @FreeCodeCamp   Text  Link   08-Jul-25

# %%
df.to_csv("Moto.csv", index= False)
